# %%
# numpy and pandas for data manipulation
import numpy as np
import pandas as pd 

# sklearn preprocessing for dealing with categorical variables
from sklearn.preprocessing import LabelEncoder

# File system manangement
import os

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
FILEPATH_INSTALLMENTS_PAYMENTS = "../data/installments_payments.csv.f"

# %%
df_installments_payments = pd.read_feather(FILEPATH_INSTALLMENTS_PAYMENTS)

# %%
df_installments_payments.head(100)
# Out:
#     SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  NUM_INSTALMENT_NUMBER  \
# 0      1054186      161674                     1.0                      6
# 1      1330831      151639                     0.0                     34
# 2      2085231      193053                     2.0                      1
# 3      2452527      199697                     1.0                      3
# 4      2714724      167756                     1.0                      2
# 5      1137312      164489                     1.0                     12
# 6      2234264      184693                     4.0                     11
# 7      1818599      111420                     2.0                      4
# 8      2723183      112102                     0.0                     14
# 9      1413990      109741                     1.0                      4
# 10     1782554      106597                     1.0                      3
# 11     2558880      154793                     1.0                      8
# 12     1570206      147645                     0.0                     20
# 13     1723268      197273                     1.0                     14
# 14     1594684      100193                     0.0                     56
# 15     1456258      118323                     1.0                      6
# 16     1053286      170192                     1.0                      7
# 17     1410565      197687                     1.0                      1
# 18     2391610      183431                     0.0                     20
# 19     2329072      183463                     1.0                     11
# 20     1354314      196570                     1.0                     14
# 21     2260765      106012                     3.0                     23
# 22     1995642      134723                     1.0                     38
# 23     2631836      140337                     0.0                    116
# 24     2702769      102122                     1.0                      1
# 25     1770345      128334                     1.0                      5
# 26     1818333      191655                     1.0                      6
# 27     1991673      162903                     0.0                     46
# 28     1184783      140804                     0.0                    106
# 29     1181315      174565                     1.0                      7
# ..         ...         ...                     ...                    ...
# 70     1873884      121871                     4.0                     10
# 71     1254935      138262                     0.0                     41
# 72     2379431      102345                     0.0                     84
# 73     1033100      135169                     1.0                      8
# 74     1193446      175313                     1.0                      5
# 75     1237335      114262                     1.0                      9
# 76     1249017      112028                     0.0                     41
# 77     2436675      145728                     1.0                     15
# 78     1306658      183774                     0.0                     49
# 79     1730720      128508                     0.0                      2
# 80     2740963      128715                     1.0                      2
# 81     1762261      151682                     0.0                     59
# 82     2318810      134177                     1.0                      4
# 83     2558325      160486                     1.0                      1
# 84     2157839      130061                     1.0                      2
# 85     1875295      137353                     0.0                    107
# 86     1185174      164662                     2.0                      5
# 87     1773564      156905                     1.0                      7
# 88     1915769      138380                     1.0                     17
# 89     2159358      128066                     1.0                      6
# 90     1362611      196368                     1.0                      3
# 91     1621283      180619                     1.0                     12
# 92     1736834      181129                     1.0                      3
# 93     2623487      174960                     1.0                     10
# 94     1850125      106619                     0.0                     59
# 95     2269581      141541                     0.0                     94
# 96     2645533      116025                     1.0                      7
# 97     2229715      168387                     1.0                     11
# 98     2664388      166612                     1.0                      5
# 99     2127195      110953                     1.0                      8
#
#     DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  AMT_INSTALMENT  AMT_PAYMENT
# 0           -1180.0             -1187.0        6948.360     6948.360
# 1           -2156.0             -2156.0        1716.525     1716.525
# 2             -63.0               -63.0       25425.000    25425.000
# 3           -2418.0             -2426.0       24350.130    24350.130
# 4           -1383.0             -1366.0        2165.040     2160.585
# 5           -1384.0             -1417.0        5970.375     5970.375
# 6            -349.0              -352.0       29432.295    29432.295
# 7            -968.0              -994.0       17862.165    17862.165
# 8            -197.0              -197.0          70.740       70.740
# 9            -570.0              -609.0       14308.470    14308.470
# 10           -933.0              -937.0       34620.525    34620.525
# 11          -1262.0             -1269.0       15031.080    15031.080
# 12           -761.0              -761.0          21.510       21.510
# 13           -755.0              -800.0        6093.990     6093.990
# 14          -1153.0             -1153.0         301.860      301.860
# 15          -2619.0             -2619.0        4844.925     4844.925
# 16           -500.0              -503.0        6882.840     6882.840
# 17          -1037.0             -1048.0       12514.050    12510.450
# 18          -1680.0             -1693.0        7875.000     7875.000
# 19          -1699.0             -1693.0        7283.295     7283.295
# 20           -361.0              -365.0       15219.000    15219.000
# 21            -56.0               -59.0       13494.915    13494.915
# 22          -1277.0             -1282.0       12949.200    12949.200
# 23           -322.0              -322.0         560.880      560.880
# 24           -281.0              -286.0        5178.195     5178.195
# 25           -240.0              -255.0       10649.925    10649.925
# 26           -345.0              -356.0       16479.270    16479.270
# 27          -2548.0             -2561.0        5400.000     5400.000
# 28           -155.0              -155.0         503.460      503.460
# 29          -1894.0             -1895.0       16274.790    16274.790
# ..              ...                 ...             ...          ...
# 70           -266.0              -267.0        1890.585     1890.585
# 71          -1176.0             -1187.0        9000.000     9000.000
# 72          -1389.0             -1396.0        8100.000     8100.000
# 73          -2176.0             -2177.0       18478.845    18478.845
# 74           -867.0              -868.0       35774.190    35774.190
# 75          -2259.0             -2290.0       10492.020    10492.020
# 76            -62.0               -62.0        1559.250     1559.250
# 77           -380.0              -378.0       13000.500    12382.560
# 78          -1567.0             -1570.0        9000.000     9000.000
# 79           -822.0              -822.0       15623.955    15623.955
# 80          -1615.0             -1618.0        8829.405     8829.405
# 81            -45.0               -48.0        1087.245      356.805
# 82            -37.0               -50.0        9309.105     9309.105
# 83          -1104.0             -1109.0       19193.175    19193.175
# 84           -832.0              -834.0       30283.290    30283.290
# 85          -1735.0             -1747.0       10800.000    10800.000
# 86          -1617.0             -1629.0        5616.585     5616.585
# 87          -1234.0             -1242.0       16234.380    16234.380
# 88          -1067.0             -1060.0       16729.155    15592.365
# 89          -2869.0             -2869.0        2978.145     2978.145
# 90           -932.0              -949.0        6412.005     6412.005
# 91          -2547.0             -2551.0        3118.770     3118.770
# 92          -2589.0             -2589.0        9829.530     9829.530
# 93           -976.0              -972.0       11463.975    11445.750
# 94          -2599.0             -2599.0         727.875      727.875
# 95           -695.0              -695.0         406.800      406.800
# 96           -873.0              -894.0        8883.945     8883.945
# 97          -1299.0             -1298.0        3020.490     3020.490
# 98          -2196.0             -2207.0       11524.815    11524.815
# 99          -1291.0             -1284.0       54752.850    54459.675
#
# [100 rows x 8 columns]

# %%
## count the number of previous installments
cnt_inst = df_installments_payments[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
df_installments_payments['SK_ID_PREV'] = df_installments_payments['SK_ID_CURR'].map(cnt_inst['SK_ID_PREV'])

## Average values for all other variables in installments payments
avg_inst = df_installments_payments.groupby('SK_ID_CURR', as_index=False).mean()
avg_inst.columns = ['i_' + f_ for f_ in avg_inst.columns]

# %%
avg_inst.rename(columns={'i_SK_ID_CURR': 'SK_ID_CURR'}, inplace=True)

# %%
avg_inst.to_feather('../data/prev_insallment_payment_feature_0819.csv.f')

# %%
avg_inst.head()
# Out:
#    SK_ID_CURR  i_SK_ID_PREV  i_NUM_INSTALMENT_VERSION  \
# 0      100001           7.0                  1.142857
# 1      100002          19.0                  1.052632
# 2      100003          25.0                  1.040000
# 3      100004           3.0                  1.333333
# 4      100005           9.0                  1.111111
#
#    i_NUM_INSTALMENT_NUMBER  i_DAYS_INSTALMENT  i_DAYS_ENTRY_PAYMENT  \
# 0                 2.714286       -2187.714286          -2195.000000
# 1                10.000000        -295.000000           -315.421053
# 2                 5.080000       -1378.160000          -1385.320000
# 3                 2.000000        -754.000000           -761.666667
# 4                 5.000000        -586.000000           -609.555556
#
#    i_AMT_INSTALMENT  i_AMT_PAYMENT
# 0       5885.132143    5885.132143
# 1      11559.247105   11559.247105
# 2      64754.586000   64754.586000
# 3       7096.155000    7096.155000
# 4       6240.205000    6240.205000
