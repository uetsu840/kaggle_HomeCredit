# %%
# numpy and pandas for data manipulation
import numpy as np
import pandas as pd 

# sklearn preprocessing for dealing with categorical variables
from sklearn.preprocessing import LabelEncoder

# File system manangement
import os

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
FILEPATH_PREVIOUS_APPLICATION  = "../data/previous_application.csv.f"

# %%
df_previous_application = pd.read_feather(FILEPATH_PREVIOUS_APPLICATION)

# %%
## count the number of previous applications for a given ID
prev_apps_count = df_previous_application[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
df_previous_application['SK_ID_PREV'] = df_previous_application['SK_ID_CURR'].map(prev_apps_count['SK_ID_PREV'])

## Average , Sum values for all other features in previous applications
prev_apps_avg = df_previous_application.groupby('SK_ID_CURR').mean().add_prefix('avg_')
#prev_apps_sum = df_previous_application.groupby('SK_ID_CURR').sum().add_prefix('sum_')
#prev_apps_avg = pd.merge(prev_apps_avg.reset_index(), prev_apps_sum.reset_index(), on='SK_ID_CURR', how='left')
prev_apps_avg = prev_apps_avg.reset_index()
prev_apps_avg.columns = ['p_' + col for col in prev_apps_avg.columns]

# %%
Sum を加えたら local validation のスコアがわずかに落ちたので、やらない。

# %%
prev_apps_avg.head(5)
# Out:
#    p_SK_ID_CURR  p_avg_SK_ID_PREV  p_avg_AMT_ANNUITY  p_avg_AMT_APPLICATION  \
# 0        100001               1.0           3951.000               24835.50
# 1        100002               1.0           9251.775              179055.00
# 2        100003               3.0          56553.990              435436.50
# 3        100004               1.0           5357.250               24282.00
# 4        100005               2.0           4813.200               22308.75
#
#    p_avg_AMT_CREDIT  p_avg_AMT_DOWN_PAYMENT  p_avg_AMT_GOODS_PRICE  \
# 0          23787.00                  2520.0                24835.5
# 1         179055.00                     0.0               179055.0
# 2         484191.00                  3442.5               435436.5
# 3          20106.00                  4860.0                24282.0
# 4          20076.75                  4464.0                44617.5
#
#    p_avg_HOUR_APPR_PROCESS_START  p_avg_NFLAG_LAST_APPL_IN_DAY  \
# ...

# %%
prev_apps_avg.rename(columns={'p_SK_ID_CURR': 'SK_ID_CURR'}, inplace=True)

# %%
prev_apps_avg.to_feather('../data/prev_app_feature_0819_2.csv.f')

# %%
prev_apps_avg.head()
# Out:
#    SK_ID_CURR  p_avg_SK_ID_PREV  p_avg_AMT_ANNUITY  p_avg_AMT_APPLICATION  \
# 0      100001               1.0           3951.000               24835.50
# 1      100002               1.0           9251.775              179055.00
# 2      100003               3.0          56553.990              435436.50
# 3      100004               1.0           5357.250               24282.00
# 4      100005               2.0           4813.200               22308.75
#
#    p_avg_AMT_CREDIT  p_avg_AMT_DOWN_PAYMENT  p_avg_AMT_GOODS_PRICE  \
# 0          23787.00                  2520.0                24835.5
# 1         179055.00                     0.0               179055.0
# 2         484191.00                  3442.5               435436.5
# 3          20106.00                  4860.0                24282.0
# 4          20076.75                  4464.0                44617.5
#
#    p_avg_HOUR_APPR_PROCESS_START  p_avg_NFLAG_LAST_APPL_IN_DAY  \
# ...

# %%
prev_apps_avg.columns
# Out:
# Index(['SK_ID_CURR', 'p_avg_SK_ID_PREV', 'p_avg_AMT_ANNUITY',
#        'p_avg_AMT_APPLICATION', 'p_avg_AMT_CREDIT', 'p_avg_AMT_DOWN_PAYMENT',
#        'p_avg_AMT_GOODS_PRICE', 'p_avg_HOUR_APPR_PROCESS_START',
#        'p_avg_NFLAG_LAST_APPL_IN_DAY', 'p_avg_RATE_DOWN_PAYMENT',
#        'p_avg_RATE_INTEREST_PRIMARY', 'p_avg_RATE_INTEREST_PRIVILEGED',
#        'p_avg_DAYS_DECISION', 'p_avg_SELLERPLACE_AREA', 'p_avg_CNT_PAYMENT',
#        'p_avg_DAYS_FIRST_DRAWING', 'p_avg_DAYS_FIRST_DUE',
#        'p_avg_DAYS_LAST_DUE_1ST_VERSION', 'p_avg_DAYS_LAST_DUE',
#        'p_avg_DAYS_TERMINATION', 'p_avg_NFLAG_INSURED_ON_APPROVAL',
#        'p_sum_SK_ID_PREV', 'p_sum_AMT_ANNUITY', 'p_sum_AMT_APPLICATION',
#        'p_sum_AMT_CREDIT', 'p_sum_AMT_DOWN_PAYMENT', 'p_sum_AMT_GOODS_PRICE',
#        'p_sum_HOUR_APPR_PROCESS_START', 'p_sum_NFLAG_LAST_APPL_IN_DAY',
#        'p_sum_RATE_DOWN_PAYMENT', 'p_sum_RATE_INTEREST_PRIMARY',
#        'p_sum_RATE_INTEREST_PRIVILEGED', 'p_sum_DAYS_DECISION',
# ...
